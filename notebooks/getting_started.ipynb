# %% [markdown]
# # Getting Started

# %%
import pandas as pd
from recsys.config import Config

# %%
config = Config()

# %%
df_train = pd.read_csv(config.data_path / 'train.csv')
df_test = pd.read_csv(config.data_path / 'test.csv')
df_item_meta = pd.read_csv(config.data_path / 'item_metadata.csv')
df_submission_popular = pd.read_csv(config.data_path / 'submission_popular.csv')

# %% [markdown]
# ### Training

# %% [markdown]
# The training data consists of two files, the sessions of the users and the features of the hotels.

# %%
df_train
# Out:
#                user_id     session_id   timestamp  step  \
# 0         008UN2RY0DMY  cd10940538005  1541031243     1
# 1         008UN2RY0DMY  cd10940538005  1541031463     2
# 2         008UN2RY0DMY  cd10940538005  1541031473     3
# 3         008UN2RY0DMY  cd10940538005  1541031473     4
# 4         008UN2RY0DMY  cd10940538005  1541031550     5
# 5         008UN2RY0DMY  cd10940538005  1541031550     6
# 6         008UN2RY0DMY  cd10940538005  1541031560     7
# 7         008UN2RY0DMY  cd10940538005  1541031560     8
# 8         008UN2RY0DMY  cd10940538005  1541031570     9
# 9         008UN2RY0DMY  cd10940538005  1541031570    10
# 10        008UN2RY0DMY  cd10940538005  1541031570    11
# 11        008UN2RY0DMY  cd10940538005  1541031570    12
# 12        008UN2RY0DMY  cd10940538005  1541031570    13
# 13        008UN2RY0DMY  cd10940538005  1541031580    14
# 14        008UN2RY0DMY  cd10940538005  1541031580    15
# 15        008UN2RY0DMY  cd10940538005  1541031580    16
# ...

# %%
df_item_meta
# Out:
#          item_id                                         properties
# 0           5121  Terrace (Hotel)|Lift|Childcare|From 3 Stars|Ra...
# 1           5555  Terrace (Hotel)|Lift|From 3 Stars|Radio|From 4...
# 2           5684  Terrace (Hotel)|Lift|From 3 Stars|Radio|4 Star...
# 3           5777  Lift|Childcare|From 3 Stars|Radio|4 Star|From ...
# 4           6044  Terrace (Hotel)|Childcare|From 3 Stars|Radio|B...
# 5           6095  Terrace (Hotel)|From 3 Stars|Radio|Minigolf|Bu...
# 6           6182  Terrace (Hotel)|From 3 Stars|Business Hotel|Re...
# 7           6257  Lift|From 3 Stars|Radio|Business Hotel|Table T...
# 8           8022  Lift|Radio|Business Hotel|Restaurant|2 Star|El...
# 9           8087  Terrace (Hotel)|Lift|From 3 Stars|Radio|From 4...
# 10          8450  Lift|From 3 Stars|Radio|4 Star|From 4 Stars|Bu...
# 11          9331  Terrace (Hotel)|Towels|Lift|Childcare|From 3 S...
# 12         11601  Terrace (Hotel)|From 3 Stars|Business Hotel|Su...
# ...

# %% [markdown]
# ### Scoring

# %% [markdown]
# The task is to predict the items (reference column) in the test set where `action_type==clickout item` and `reference==NaN`.

# %%
df_test[(df_test['action_type']=='clickout item') & (df_test['reference'].isnull())]
# Out:
#               user_id     session_id   timestamp  step    action_type  \
# 9        000324D9BBUC  89643988fdbfb  1541593942    10  clickout item
# 10       0004Q49X39PY  9de47d9a66494  1541641157     1  clickout item
# 11       0004Q49X39PY  beea5c27030cb  1541561202     1  clickout item
# 13       00071784XQ6B  9617600e1ba7c  1541630328     2  clickout item
# 19       0008BO33KUQ0  2d0e2102ee0dc  1541636411     6  clickout item
# 21       000GO9NY6P4M  55dbafdbb9bab  1541594662     2  clickout item
# 37       000IRHJS2DL9  f6ffffd20d43d  1541605541    12  clickout item
# 38       000JB0UNEH23  7df07dc9fe26e  1541618174     1  clickout item
# 41       000OWRCYEHKT  53e84da5c2dad  1541706095     3  clickout item
# 45       000VBY1D6BP8  033fddaaa99af  1541587306     4  clickout item
# 49       00130PO6XSZR  0d5fe519827f3  1541701777     1  clickout item
# 57       0013L641G5P2  05a5589dd7b92  1541694563     8  clickout item
# ...

# %%
df_test
# Out:
#               user_id     session_id   timestamp  step  \
# 0        000324D9BBUC  89643988fdbfb  1541593272     1
# 1        000324D9BBUC  89643988fdbfb  1541593820     2
# 2        000324D9BBUC  89643988fdbfb  1541593882     3
# 3        000324D9BBUC  89643988fdbfb  1541593882     4
# 4        000324D9BBUC  89643988fdbfb  1541593902     5
# 5        000324D9BBUC  89643988fdbfb  1541593902     6
# 6        000324D9BBUC  89643988fdbfb  1541593931     7
# 7        000324D9BBUC  89643988fdbfb  1541593941     8
# 8        000324D9BBUC  89643988fdbfb  1541593941     9
# 9        000324D9BBUC  89643988fdbfb  1541593942    10
# 10       0004Q49X39PY  9de47d9a66494  1541641157     1
# 11       0004Q49X39PY  beea5c27030cb  1541561202     1
# 12       00071784XQ6B  9617600e1ba7c  1541630272     1
# 13       00071784XQ6B  9617600e1ba7c  1541630328     2
# 14       0008BO33KUQ0  2d0e2102ee0dc  1541635958     1
# 15       0008BO33KUQ0  2d0e2102ee0dc  1541635992     2
# ...

# %% [markdown]
# ### Sample Submission

# %% [markdown]
# The submission_popular contains a sample submission. Note that not only one item is predicted, but a ranking of items. Note further, that the items are the same as in impressions, just with a different order. Thus, the task is to rank the impressions (candidate items) in the best way.

# %%
display(df_submission_popular)
# Out:
#              user_id     session_id   timestamp  step  \
# 0       000324D9BBUC  89643988fdbfb  1541593942    10
# 1       0004Q49X39PY  9de47d9a66494  1541641157     1
# 2       0004Q49X39PY  beea5c27030cb  1541561202     1
# 3       00071784XQ6B  9617600e1ba7c  1541630328     2
# 4       0008BO33KUQ0  2d0e2102ee0dc  1541636411     6
# 5       000GO9NY6P4M  55dbafdbb9bab  1541594662     2
# 6       000IRHJS2DL9  f6ffffd20d43d  1541605541    12
# 7       000JB0UNEH23  7df07dc9fe26e  1541618174     1
# 8       000OWRCYEHKT  53e84da5c2dad  1541706095     3
# 9       000VBY1D6BP8  033fddaaa99af  1541587306     4
# 10      00130PO6XSZR  0d5fe519827f3  1541701777     1
# 11      0013L641G5P2  05a5589dd7b92  1541694563     8
# 12      0015X90DOWT1  6ed36662b8da9  1541617000     3
# 13      0017FIR55K7R  f2787447a02eb  1541607094     3
# 14      001D536Q4S8D  7480cfb2714a9  1541705106     1
# 15      001I0INS8EBP  8db447f4acfd4  1541665607     7
# ...
